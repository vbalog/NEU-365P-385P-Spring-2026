# %%
# %%html
# <link rel="stylesheet" type="text/css" href="rise.css" />
# Out:
# <link rel="stylesheet" type="text/css" href="rise.css" />

# %%
import numpy as np
import matplotlib.pyplot as plt
# %config InlineBackend.figure_format = 'retina'
plt.style.use('bmh')
plt.rcParams['figure.figsize'] = [8, 6]

# %% [markdown]
# # [PyTorch](https://pytorch.org)
# ```
# pip install torch
# ```

# %%
import torch
from torch import nn

# %% [markdown]
# To construct your neural network in PyTorch you create a class that inherits from `torch.nn.Module`.

# %%
class MyAwesomeNeuralNetwork(nn.Module):
    ...

# %% [markdown]
# In your network's initialization method, you first must initialize `nn.Module`.

# %%
class MyAwesomeNeuralNetwork(nn.Module):

    def __init__(self):
        nn.Module.__init__(self)

# %% [markdown]
# Next, you define the various components of your network.

# %%
class MyAwesomeNeuralNetwork(nn.Module):
    
    def __init__(self):
        nn.Module.__init__(self)

        # 10 inputs -> 5 neurons in hidden layer
        self.hidden_layer = nn.Linear(10, 5)
        
        # 5 neurons in hidden layer -> 1 neuron in output layer
        self.output_layer = nn.Linear(5, 1)

# %% [markdown]
# Finally, you must define the forward pass method which takes an input (e.g., `x10`), passes it through your network components, and returns the network's output (e.g., `x1`).

# %%
class MyAwesomeNeuralNetwork(nn.Module):
    
    def __init__(self):
        nn.Module.__init__(self)

        # 10 inputs -> 5 neurons in hidden layer
        self.hidden_layer = nn.Linear(10, 5)
        
        # 5 neurons in hidden layer -> 1 neuron in output layer
        self.output_layer = nn.Linear(5, 1)

    def forward(self, x10):
        # x10 MUST be an array of length 10

        # hidden layer linear transform
        x5 = self.hidden_layer(x10)
        
        # activation function for 5 outputs from hidden layer
        relu = nn.ReLU()
        x5 = relu(x5)

        # output layer linear transform
        x1 = self.output_layer(x5)
        
        # return final output
        return x1

# %% [markdown]
# The same code without comments...

# %%
class MyAwesomeNeuralNetwork(nn.Module):
    
    def __init__(self):
        nn.Module.__init__(self)

        self.hidden_layer = nn.Linear(10, 5)
        self.output_layer = nn.Linear(5, 1)

    def forward(self, x10):
        x5 = torch.relu(self.hidden_layer(x10))
        x1 = self.output_layer(x5)
        return x1

# %% [markdown]
# An easier way to define sequential layers in your network...

# %%
class MyAwesomeNeuralNetwork(nn.Module):
    
    def __init__(self):
        nn.Module.__init__(self)

        self.main = nn.Sequential(
            nn.Linear(10, 5),
            nn.ReLU(),
            nn.Linear(5, 1)
        )

    def forward(self, x10):
        x1 = self.main(x10)
        return x1

# %% [markdown]
# Diabetes score as a function of 10 other measures in human patients

# %%
import pandas as pd

# Measures of various features and diabetes disease progression for 442 patients.
# Available at https://www4.stat.ncsu.edu/~boos/var.select/diabetes.tab.txt
dis = pd.read_csv('data/diabetes.csv')
dis
# Out:
#      AGE  SEX   BMI      BP   TC    LDL   HDL   TCH     LTG  GLU  DIS
# 0     59    2  32.1  101.00  157   93.2  38.0  4.00  4.8598   87  151
# 1     48    1  21.6   87.00  183  103.2  70.0  3.00  3.8918   69   75
# 2     72    2  30.5   93.00  156   93.6  41.0  4.00  4.6728   85  141
# 3     24    1  25.3   84.00  198  131.4  40.0  5.00  4.8903   89  206
# 4     50    1  23.0  101.00  192  125.4  52.0  4.00  4.2905   80  135
# ..   ...  ...   ...     ...  ...    ...   ...   ...     ...  ...  ...
# 437   60    2  28.2  112.00  185  113.8  42.0  4.00  4.9836   93  178
# 438   47    2  24.9   75.00  225  166.0  42.0  5.00  4.4427  102  104
# 439   60    2  24.9   99.67  162  106.6  43.0  3.77  4.1271   95  132
# 440   36    1  30.0   95.00  201  125.2  42.0  4.79  5.1299   85  220
# 441   36    1  19.6   71.00  250  133.2  97.0  3.00  4.5951   92   57
#
# [442 rows x 11 columns]

# %% [markdown]
# Extract feature and target variables from the dataframe.

# %%
X = dis.loc[:,'AGE':'GLU']
y = dis['DIS']

X.shape, y.shape
# Out:
# ((442, 10), (442,))

# %% [markdown]
# Split the dataset into training and testing sets.
#
# You'll train your models on the training set and evaluate their error on the testing set.

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, shuffle=True, test_size=0.4, random_state=3)

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((265, 10), (177, 10), (265,), (177,))

# %% [markdown]
# Standardize the data.

# %%
means = X_train.mean()
stds = X_train.std()

X_train = (X_train - means) / stds
X_test = (X_test - means) / stds

X_train.mean(), X_train.var()
# Out:
# (AGE   -2.010970e-17
#  SEX    1.340647e-16
#  BMI   -8.043880e-17
#  BP     9.552108e-16
#  TC     2.681293e-16
#  LDL    1.943938e-16
#  HDL    2.815358e-16
#  TCH   -8.580139e-16
#  LTG    1.943938e-16
#  GLU   -5.195006e-17
#  dtype: float64,
#  AGE    1.0
#  SEX    1.0
#  BMI    1.0
#  BP     1.0
#  TC     1.0
#  LDL    1.0
#  HDL    1.0
#  TCH    1.0
#  LTG    1.0
#  GLU    1.0
#  dtype: float64)

# %% [markdown]
# Get features for first patient in test set.

# %%
patient = X_test.iloc[0,:]
patient
# Out:
# AGE   -0.532290
# SEX    1.097166
# BMI   -0.327719
# BP    -0.609865
# TC     0.162966
# LDL    0.063730
# HDL    0.886617
# TCH   -0.779989
# LTG   -0.461617
# GLU    0.228827
# Name: 229, dtype: float64

# %% [markdown]
# To convert back from standardized to original units.

# %%
patient * stds + means
# Out:
# AGE     41.000
# SEX      2.000
# BMI     24.900
# BP      86.000
# TC     192.000
# LDL    115.000
# HDL     61.000
# TCH      3.000
# LTG      4.382
# GLU     94.000
# dtype: float64

# %% [markdown]
# PyTorch needs data to be converted into a PyTorch Tensor.
#
# *Tensors are essentially the same thing as NumPy N-dimensional arrays.*
#
# The reason for a new `tensor` class rather than simply using NumPy `ndarray` is to include special optimization for several manipulations important for neural networks including performing operations on the GPU in addition to the CPU and calculating gradients of the loss function.
#
# *PyTorch tensors are easily created from NumPy arrays.*

# %%
patient_tensor = torch.tensor(patient.to_numpy())
patient_tensor
# Out:
# tensor([-0.5323,  1.0972, -0.3277, -0.6099,  0.1630,  0.0637,  0.8866, -0.7800,
#         -0.4616,  0.2288], dtype=torch.float64)

# %% [markdown]
# PyTorch tensors behave much the same way as NumPy arrays.

# %%
patient_tensor.shape, patient_tensor.dtype
# Out:
# (torch.Size([10]), torch.float64)

# %%
patient_tensor[:3]
# Out:
# tensor([-0.5323,  1.0972, -0.3277], dtype=torch.float64)

# %% [markdown]
# Let's take a look at how some of our model components convert inputs into outputs.

# %%
linear = nn.Linear(10, 5)

output = linear(patient_tensor)
output
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[13], line 3
#       1 linear = nn.Linear(10, 5)
# ----> 3 output = linear(patient_tensor)
#       4 output
#
# File /opt/miniconda3/envs/neu365/lib/python3.12/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File /opt/miniconda3/envs/neu365/lib/python3.12/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File /opt/miniconda3/envs/neu365/lib/python3.12/site-packages/torch/nn/modules/linear.py:116, in Linear.forward(self, input)
#     115 def forward(self, input: Tensor) -> Tensor:
# --> 116     return F.linear(input, self.weight, self.bias)
#
# RuntimeError: mat1 and mat2 must have the same dtype, but got Double and Float

# %% [markdown]
# By default (you can change this if you want), PyTorch networks use 32-bit floating point precision.
#
# This clashes with NumPy's default 64-bit floating point precision.

# %%
torch.float
# Out:
# torch.float32

# %%
patient_tensor = torch.tensor(patient.to_numpy())
patient_tensor.dtype
# Out:
# torch.float64

# %% [markdown]
# It is simple to convert your inputs into 32-bit tensors.

# %%
patient_tensor = torch.tensor(patient.to_numpy(), dtype=torch.float)
patient_tensor.dtype
# Out:
# torch.float32

# %%
patient_tensor = torch.tensor(patient.to_numpy()).float()
patient_tensor.dtype
# Out:
# torch.float32

# %% [markdown]
# Now you can feed the patient input to, for example, a PyTorch linear transform.

# %%
linear = nn.Linear(10, 5)

output = linear(patient_tensor)
output
# Out:
# tensor([-0.2622, -0.4236,  0.2784,  0.0407, -0.1005], grad_fn=<ViewBackward0>)

# %% [markdown]
# You can inspect all of the parameters of the linear transform.

# %%
linear.weight.shape, linear.bias.shape
# Out:
# (torch.Size([5, 10]), torch.Size([5]))

# %%
linear.weight, linear.bias
# Out:
# (Parameter containing:
#  tensor([[ 0.2807, -0.0799,  0.1132, -0.1490, -0.1708, -0.1385, -0.1057,  0.0499,
#            0.1802,  0.0720],
#          [-0.2623, -0.1443, -0.0970,  0.0105,  0.2088,  0.1222,  0.0191,  0.2822,
#            0.2940, -0.0245],
#          [-0.0690,  0.2401, -0.0615,  0.1593, -0.1572,  0.1584, -0.1733, -0.0411,
#           -0.2490,  0.2692],
#          [-0.1639, -0.0917,  0.3068, -0.1531, -0.0696,  0.1770,  0.1623,  0.0888,
#           -0.2211,  0.2547],
#          [ 0.1017, -0.2535,  0.3072, -0.2819,  0.2041,  0.2672,  0.0922, -0.0332,
#           -0.1256, -0.0575]], requires_grad=True),
#  Parameter containing:
#  tensor([ 0.1571, -0.1277,  0.0158, -0.1736, -0.0422], requires_grad=True))

# %% [markdown]
# Let's pass this output to the ReLU activation function.

# %%
output
# Out:
# tensor([-0.2622, -0.4236,  0.2784,  0.0407, -0.1005], grad_fn=<ViewBackward0>)

# %%
activation = nn.ReLU()
activation(output)
# Out:
# tensor([0.0000, 0.0000, 0.2784, 0.0407, 0.0000], grad_fn=<ReluBackward0>)

# %% [markdown]
# Let's return to your fully defined neural network.

# %%
class MyAwesomeNeuralNetwork(nn.Module):
    
    def __init__(self):
        nn.Module.__init__(self)

        self.sequential_layers = nn.Sequential(
            nn.Linear(10, 5),
            nn.ReLU(),
            nn.Linear(5, 1)
        )

    def forward(self, x10):
        x1 = self.sequential_layers(x10)
        return x1

# %% [markdown]
# First, you'll need to create an instance of this network.

# %%
net = MyAwesomeNeuralNetwork()

# %% [markdown]
# Then you can feed it input and get it's output in much the same way as for the individual components within it. *Note that you DO NOT call `net.forward()` explicitly.*

# %%
dis_prediction = net(patient_tensor)
dis_prediction
# Out:
# tensor([-0.5447], grad_fn=<ViewBackward0>)

# %% [markdown]
# Convert dataset to PyTorch tensors.

# %%
X_train = torch.tensor(X_train.to_numpy(), dtype=torch.float)
X_test = torch.tensor(X_test.to_numpy(), dtype=torch.float)
y_train = torch.tensor(y_train.to_numpy(), dtype=torch.float)
y_test = torch.tensor(y_test.to_numpy(), dtype=torch.float)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# (torch.Size([265, 10]),
#  torch.Size([177, 10]),
#  torch.Size([265]),
#  torch.Size([177]))

# %% [markdown]
# PyTorch likes being explicit about all array dimensions.

# %%
y_train = y_train.reshape([-1,1])
y_test = y_test.reshape([-1,1])
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# (torch.Size([265, 10]),
#  torch.Size([177, 10]),
#  torch.Size([265, 1]),
#  torch.Size([177, 1]))

# %% [markdown]
# If you input an array of sample arrays, you will get an output for each sample.

# %%
y_test_prediction = net(X_test)
y_test_prediction.shape
# Out:
# torch.Size([177, 1])

# %% [markdown]
# Let's see how well your network is doing at predicting diabetes disease scores based on patient data.

# %%
plt.plot(y_test, y_test_prediction, 'o')
plt.xlabel('True Disease Score')
plt.ylabel('Predicted Disease Score');
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 plt.plot(y_test, y_test_prediction, 'o')
#       2 plt.xlabel('True Disease Score')
#       3 plt.ylabel('Predicted Disease Score');
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/neu365p4/lib/python3.13/site-packages/matplotlib/pyplot.py:3827, in plot(scalex, scaley, data, *args, **kwargs)
#    3819 @_copy_docstring_and_deprecators(Axes.plot)
#    3820 def plot(
#    3821     *args: float | ArrayLike | str,
#    (...)   3825     **kwargs,
#    3826 ) -> list[Line2D]:
# -> 3827     return gca().plot(
#    3828         *args,
#    3829         scalex=scalex,
#    3830         scaley=scaley,
#    3831         **({"data": data} if data is not None else {}),
#    3832         **kwargs,
#    3833     )
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/neu365p4/lib/python3.13/site-packages/matplotlib/axes/_axes.py:1777, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1534 """
#    1535 Plot y versus x as lines and/or markers.
#    1536
#    (...)   1774 (``'green'``) or hex strings (``'#008000'``).
#    1775 """
#    1776 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1777 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1778 for line in lines:
#    1779     self.add_line(line)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/neu365p4/lib/python3.13/site-packages/matplotlib/axes/_base.py:297, in _process_plot_var_args.__call__(self, axes, data, return_kwargs, *args, **kwargs)
#     295     this += args[0],
#     296     args = args[1:]
# --> 297 yield from self._plot_args(
#     298     axes, this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey,
#     299     return_kwargs=return_kwargs
#     300 )
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/neu365p4/lib/python3.13/site-packages/matplotlib/axes/_base.py:484, in _process_plot_var_args._plot_args(self, axes, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     482 if len(xy) == 2:
#     483     x = _check_1d(xy[0])
# --> 484     y = _check_1d(xy[1])
#     485 else:
#     486     x, y = index_of(xy[-1])
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/neu365p4/lib/python3.13/site-packages/matplotlib/cbook.py:1361, in _check_1d(x)
#    1359 """Convert scalars to 1D arrays; pass-through arrays as is."""
#    1360 # Unpack in case of e.g. Pandas or xarray object
# -> 1361 x = _unpack_to_numpy(x)
#    1362 # plot requires `shape` and `ndim`.  If passed an
#    1363 # object that doesn't provide them, then force to numpy array.
#    1364 # Note this will strip unit information.
#    1365 if (not hasattr(x, 'shape') or
#    1366         not hasattr(x, 'ndim') or
#    1367         len(x.shape) < 1):
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/neu365p4/lib/python3.13/site-packages/matplotlib/cbook.py:2371, in _unpack_to_numpy(x)
#    2365         return xtmp
#    2366 if _is_torch_array(x) or _is_jax_array(x) or _is_tensorflow_array(x):
#    2367     # using np.asarray() instead of explicitly __array__(), as the latter is
#    2368     # only _one_ of many methods, and it's the last resort, see also
#    2369     # https://numpy.org/devdocs/user/basics.interoperability.html#using-arbitrary-objects-in-numpy
#    2370     # therefore, let arrays do better if they can
# -> 2371     xtmp = np.asarray(x)
#    2373     # In case np.asarray method does not return a numpy array in future
#    2374     if isinstance(xtmp, np.ndarray):
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/neu365p4/lib/python3.13/site-packages/torch/_tensor.py:1194, in Tensor.__array__(self, dtype)
#    1192     return handle_torch_function(Tensor.__array__, (self,), self, dtype=dtype)
#    1193 if dtype is None:
# -> 1194     return self.numpy()
#    1195 else:
#    1196     return self.numpy().astype(dtype, copy=False)
#
# RuntimeError: Can't call numpy() on Tensor that requires grad. Use tensor.detach().numpy() instead.

# %% [markdown]
# For plotting Matplotlib, you need to convert your PyTorch tensor back to a NumPy ndarray.
#
# Before you can do this, you need to `detach` the tensor from the graph it uses to compute gradients.

# %%
plt.plot(y_test, y_test_prediction.detach().numpy(), 'o')
plt.xlabel('True Disease Score')
plt.ylabel('Predicted Disease Score')
plt.title("What do you think of your network's performance?");

# %% [markdown]
# Of course you must train your network before it is of any use.
#
# First, you need some *measure of the error (loss)*.

# %%
# mean squared error loss function
loss_fn = nn.MSELoss()

# %%
loss = loss_fn(y_test_prediction, y_test)
loss
# Out:
# tensor(28253.5078, grad_fn=<MseLossBackward0>)

# %% [markdown]
# Next, you need a *method for updating the model parameters based on the gradients of the loss with respect to each parameter*.

# %%
# stochastic gradient descent optimizer
# lr = learning rate
optimizer = torch.optim.SGD(net.parameters(), lr=1e-3)

# %% [markdown]
# Next, you need to define a function for training the model (i.e., on a training set).

# %%
def train(X, y, model, loss_fn, optimizer):
    # Put the model into training mode.
    model.train()

    # Compute prediction error
    pred = model(X)
    loss = loss_fn(pred, y)

    # Backpropagation
    # Compute gradient of loss and update model parameters to reduce loss
    loss.backward()
    optimizer.step()
    optimizer.zero_grad()

    # Return loss so we can keep track of it
    # .item() extracts float value from single-valued tensor
    return loss.item()

# %% [markdown]
# Next, you should also define a function for evaluating the model's performance (i.e., on a testing set).

# %%
def test(X, y, model, loss_fn):
    # Put the model into evaluation mode.
    model.eval()

    # Do NOT compute unecessary gradients during evaluation.
    with torch.no_grad():
        pred = model(X)
        loss = loss_fn(pred, y)

    # Return loss so we can keep track of it
    # .item() extracts float value from single-valued tensor
    return loss.item()

# %% [markdown]
# Now train the model for some number of iterations (epochs) and keep track of the training and testing loss along the way.

# %%
model = MyAwesomeNeuralNetwork()
loss_fn = nn.MSELoss()
optimizer = torch.optim.SGD(model.parameters(), lr=1e-3)

# %%
epochs = 5
train_loss = []
test_loss = []

for t in range(epochs):
    loss = train(X_train, y_train, model, loss_fn, optimizer)
    train_loss.append(loss)
    
    loss = test(X_test, y_test, model, loss_fn)
    test_loss.append(loss)

# %% [markdown]
# Visualize network training progress...

# %%
plt.figure(figsize=[12,6])
plt.subplot(1, 2, 1)
plt.plot(train_loss)
plt.xlabel('Epoch')
plt.ylabel('Train loss')
plt.subplot(1, 2, 2)
plt.plot(test_loss)
plt.xlabel('Epoch')
plt.ylabel('Test loss');

# %% [markdown]
# Let's keep training starting from where we left off.

# %%
epochs = 95

for t in range(epochs):
    loss = train(X_train, y_train, model, loss_fn, optimizer)
    train_loss.append(loss)
    
    loss = test(X_test, y_test, model, loss_fn)
    test_loss.append(loss)

# %%
plt.figure(figsize=[12,6])
plt.subplot(1, 2, 1)
plt.plot(train_loss)
plt.xlabel('Epoch')
plt.ylabel('Train loss')
plt.subplot(1, 2, 2)
plt.plot(test_loss)
plt.xlabel('Epoch')
plt.ylabel('Test loss');

# %% [markdown]
# Let's keep training starting from where we left off.

# %%
epochs = 100

for t in range(epochs):
    loss = train(X_train, y_train, model, loss_fn, optimizer)
    train_loss.append(loss)
    
    loss = test(X_test, y_test, model, loss_fn)
    test_loss.append(loss)

# %%
plt.figure(figsize=[12,6])
plt.subplot(1, 2, 1)
plt.plot(train_loss)
plt.xlabel('Epoch')
plt.ylabel('Train loss')
plt.subplot(1, 2, 2)
plt.plot(test_loss)
plt.xlabel('Epoch')
plt.ylabel('Test loss');

# %% [markdown]
# Let's see how well your network is doing at predicting diabetes disease scores based on patient data.

# %%
y_test_prediction_before_training = y_test_prediction.clone()
y_test_prediction_after_training = model(X_test)

# %%
plt.figure(figsize=[12,6])
plt.subplot(1, 2, 1)
plt.plot(y_test, y_test_prediction_before_training.detach().numpy(), 'o')
plt.xlabel('True Disease Score')
plt.ylabel('Predicted Disease Score')
plt.title('Before training')
plt.subplot(1, 2, 2)
plt.plot(y_test, y_test_prediction_after_training.detach().numpy(), 'o')
plt.xlabel('True Disease Score')
plt.ylabel('Predicted Disease Score')
plt.title('After training');

# %% [markdown]
# Let's save your awesome network now that it's trained.

# %%
torch.save(model.state_dict(), "my-awesome-net.pth")

# %% [markdown]
# Let's create a new instance of `MyAwesomeNetwork` and load in the previously trained parameters.

# %%
net = MyAwesomeNeuralNetwork()

net.load_state_dict(torch.load("my-awesome-net.pth"))
# Out:
# <All keys matched successfully>

# %% [markdown]
# Visualize prediction for loaded model to verify it is all good.

# %%
y_test_prediction = net(X_test)

plt.plot(y_test, y_test_prediction.detach().numpy(), 'o')
plt.xlabel('True Disease Score')
plt.ylabel('Predicted Disease Score')
plt.title('Reloaded from file');

# %% [markdown]
# ### Exercise
# I invite you to try training this same network using the dataset without standardization, and compare how well it does.

# %% [markdown]
# # Batches
#
# **Often it is not possible to fit an entire dataset into working memory.**
#
# Thus, it is typical that **datasets are split into batches** and that a *model is trained on each batch separately*.

# %% [markdown]
# PyTorch offers some convenient objects for working with datasets split into batches.

# %%
from torch.utils.data import TensorDataset, DataLoader

train_dataset = TensorDataset(X_train, y_train)
test_dataset = TensorDataset(X_test, y_test)

train_dataloader = DataLoader(train_dataset, batch_size=64, shuffle=True)
test_dataloader = DataLoader(test_dataset, batch_size=64, shuffle=True)

# %% [markdown]
# Let's slightly edit our training function to iterate over batches.

# %%
def train_loop(dataloader, model, loss_fn, optimizer):
    # Set the model to training mode - important for batch normalization and dropout layers
    # Unnecessary in this situation but added for best practices
    model.train()
    
    num_batches = len(dataloader)
    train_loss = 0

    # Train on one batch at a time,
    # looping over all batches in the entire dataset
    for batch, (X, y) in enumerate(dataloader):
        # Compute prediction and loss
        pred = model(X)
        loss = loss_fn(pred, y)
        train_loss += loss.item()

        # Backpropagation
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()

    # Average train error over batches
    train_loss /= num_batches

    return train_loss

# %% [markdown]
# Let's slightly edit our evaluation function to iterate over batches.

# %%
def test_loop(dataloader, model, loss_fn):
    # Set the model to evaluation mode - important for batch normalization and dropout layers
    # Unnecessary in this situation but added for best practices
    model.eval()
    
    num_batches = len(dataloader)
    test_loss = 0

    # Evaluating the model with torch.no_grad() ensures that no gradients are computed during test mode
    # also serves to reduce unnecessary gradient computations and memory usage for tensors with requires_grad=True
    with torch.no_grad():
        # Test error per batch...
        for X, y in dataloader:
            pred = model(X)
            loss = loss_fn(pred, y)
            test_loss += loss.item()

    # Average test error over batches
    test_loss /= num_batches

    return test_loss

# %% [markdown]
# Now training your network is pretty much the same as before...

# %%
model = MyAwesomeNeuralNetwork()
loss_fn = nn.MSELoss()
optimizer = torch.optim.SGD(model.parameters(), lr=1e-3)

# %%
epochs = 200
train_loss = []
test_loss = []

for t in range(epochs):
    loss = train_loop(train_dataloader, model, loss_fn, optimizer)
    train_loss.append(loss)
    
    loss = test_loop(test_dataloader, model, loss_fn)
    test_loss.append(loss)

# %%
plt.figure(figsize=[12,6])
plt.subplot(1, 2, 1)
plt.plot(train_loss)
plt.xlabel('Epoch')
plt.ylabel('Train loss')
plt.subplot(1, 2, 2)
plt.plot(test_loss)
plt.xlabel('Epoch')
plt.ylabel('Test loss');

# %% [markdown]
# Visualize model prediction.

# %%
y_test_prediction = model(X_test)

plt.plot(y_test, y_test_prediction.detach().numpy(), 'o')
plt.xlabel('True Disease Score')
plt.ylabel('Predicted Disease Score')
plt.title('Reloaded from file');

# %% [markdown]
# # GPU vs. CPU
#
# A major advantage of PyTorch's tensor over NumPy's ndarray is that it is built to work with GPUs.
#
# All of *your data and your model can either live on the CPU or on the GPU*, and you can move them back and forth.
#
# However, **a model on the GPU doesn't know about data on the CPU, and vice-versa**. So you have to make sure both your model and your data are moved to the same device before you attempt any computations.

# %% [markdown]
# You can query what options are available to you on your current machine.

# %%
# Get cpu, gpu or mps device for training.
device = (
    "cuda" if torch.cuda.is_available()
    else "mps" if torch.backends.mps.is_available()
    else "cpu"
)
device
# Out:
# 'mps'

# %% [markdown]
# Let's slightly edit your training function to move batch data to your selected device.

# %%
def train_loop(dataloader, model, loss_fn, optimizer):
    # Set the model to training mode - important for batch normalization and dropout layers
    # Unnecessary in this situation but added for best practices
    model.train()
    
    num_batches = len(dataloader)
    train_loss = 0

    # Train on one batch at a time,
    # looping over all batches in the entire dataset
    for batch, (X, y) in enumerate(dataloader):
        # Move data to device
        X, y = X.to(device), y.to(device)
        
        # Compute prediction and loss
        pred = model(X)
        loss = loss_fn(pred, y)
        train_loss += loss.item()

        # Backpropagation
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()

    # Average train error over batches
    train_loss /= num_batches

    return train_loss

# %% [markdown]
# Let's slightly edit your evaluation function to move batch data to your selected device.

# %%
def test_loop(dataloader, model, loss_fn):
    # Set the model to evaluation mode - important for batch normalization and dropout layers
    # Unnecessary in this situation but added for best practices
    model.eval()
    
    num_batches = len(dataloader)
    test_loss = 0

    # Evaluating the model with torch.no_grad() ensures that no gradients are computed during test mode
    # also serves to reduce unnecessary gradient computations and memory usage for tensors with requires_grad=True
    with torch.no_grad():
        # Test error per batch...
        for X, y in dataloader:
            # Move data to device
            X, y = X.to(device), y.to(device)
            
            # Compute prediction and loss
            pred = model(X)
            loss = loss_fn(pred, y)
            test_loss += loss.item()

    # Average test error over batches
    test_loss /= num_batches

    return test_loss

# %% [markdown]
# Now training your network is pretty much the same as before except you need to rememeber to also move your model to your selected device.

# %%
model = MyAwesomeNeuralNetwork().to(device)
loss_fn = nn.MSELoss()
optimizer = torch.optim.SGD(model.parameters(), lr=1e-3)

# %%
epochs = 200
train_loss = []
test_loss = []

for t in range(epochs):
    loss = train_loop(train_dataloader, model, loss_fn, optimizer)
    train_loss.append(loss)
    
    loss = test_loop(test_dataloader, model, loss_fn)
    test_loss.append(loss)

# %%
plt.figure(figsize=[12,6])
plt.subplot(1, 2, 1)
plt.plot(train_loss)
plt.xlabel('Epoch')
plt.ylabel('Train loss')
plt.subplot(1, 2, 2)
plt.plot(test_loss)
plt.xlabel('Epoch')
plt.ylabel('Test loss');

# %% [markdown]
# To get the model prediction, make sure both the model and the data are on the same device.

# %%
y_test_prediction = model(X_test)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 y_test_prediction = model(X_test)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/neu365p4/lib/python3.13/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/neu365p4/lib/python3.13/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# Cell In[22], line 13, in MyAwesomeNeuralNetwork.forward(self, x10)
#      12 def forward(self, x10):
# ---> 13     x1 = self.sequential_layers(x10)
#      14     return x1
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/neu365p4/lib/python3.13/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/neu365p4/lib/python3.13/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/neu365p4/lib/python3.13/site-packages/torch/nn/modules/container.py:250, in Sequential.forward(self, input)
#     248 def forward(self, input):
#     249     for module in self:
# --> 250         input = module(input)
#     251     return input
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/neu365p4/lib/python3.13/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/neu365p4/lib/python3.13/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/neu365p4/lib/python3.13/site-packages/torch/nn/modules/linear.py:125, in Linear.forward(self, input)
#     124 def forward(self, input: Tensor) -> Tensor:
# --> 125     return F.linear(input, self.weight, self.bias)
#
# RuntimeError: Tensor for argument input is on cpu but expected on mps

# %% [markdown]
# To get the model prediction, make sure both the model and the data are on the same device.

# %%
y_test_prediction_on_device = model(X_test.to(device))

y_test_prediction_on_cpu = y_test_prediction_on_device.cpu()

y_test_prediction_numpy = y_test_prediction_on_cpu.detach().numpy()

plt.plot(y_test, y_test_prediction_numpy, 'o')
plt.xlabel('True Disease Score')
plt.ylabel('Predicted Disease Score')
plt.title('Reloaded from file');
