# %% [markdown]
# # Hidden Markov Model (9 pts)
#
# ---
# ### Collaborators
# You MUST include a bulleted list with the full names of everyone you collaborated with on this assignment.
# - Jane Doe
# - John Doe
#
# ---
# The questions refer to the obsereved data sequence in the file `hmm-data-seq.npy` which is located in the same directory as this notebook file.

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams["figure.figsize"] = (15, 5)

# must be in the current folder
# length 10,000 data sequence (in data/ folder relative to this notebook)
data_seq = np.load('data/hmm-data-seq.npy')

plt.plot(data_seq[:1000])
plt.xlabel('Time pt')
plt.ylabel('Emission amplitude')

data_seq.shape
# Out:
# (10000,)

# %% [markdown]
# 1. (3 pts) Postulate a hidden Markov model that could plausibly explain the observed data sequence shown above. Setup the model using pomegranate. Hint: Keep things simple. Use the minimum number of states you think you might need to explain the data and assume that each state emits random observed values following a normal distribution. Also, take a look at the data sequence to get an idea of what is going on. Postulate what transitions between the states should be allowed in your model and only set those specific transitions to have non-zero probability. I recommend not worrying too much about the specific values for your non-zero transition probabilites: maybe just set each state as having 90% chance to stay in the state (this means events will last 9 frames on average) and 10% chance to go to other states (split the 10% up amongs all other states that can be reached), then let the optimizer figure out the best values for these parameters (this will be done in the next question).

# %% [markdown]
# 2. (3 pts) Optimize your model parameters based on the data sequence.

# %% [markdown]
# 3. (3 pts) Predict the most likely sequence of hidden states that would explain the observation sequence. Plot the first 1000 data points of the observation sequence and color each data point according to it's predicted most likely hidden state (e.g., see the lecture).
